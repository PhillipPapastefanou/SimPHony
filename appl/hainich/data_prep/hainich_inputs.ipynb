# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/pp/Documents/Repos/plant_hydro_standalone/data/hainich/input/Meteo_Hainich_dT30min_forcing_PHS.csv")

# %%
df[['SM_08','SM_16','SM_32']].max().mean()
# Out:
# 48.69333333333333

# %%
df[['SM_08','SM_16','SM_32']].min()
# Out:
# SM_08    18.205
# SM_16    18.660
# SM_32    27.160
# dtype: float64

# %%
df['SWDR_4400'].max()
# Out:
# 972.935
