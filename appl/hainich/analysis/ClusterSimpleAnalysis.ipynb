# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os

# %%
root_output_directory = "/Users/pp/data/Simulations/A08_Hydraulics_standalone/hainich"

# %%
os.listdir(root_output_directory)
# Out:
# ['.DS_Store',
#  'vanGenuch_fine',
#  'broad_campbell_close',
#  'cluster_full',
#  'broad_local_anet_fix',
#  'fine_vanGenuch_jul',
#  'fine_vanGenuch_jul_diff_err',
#  'cluster_camp_broad',
#  'broad_local_test',
#  'cluster_close']

# %%
root_output_directory = "/Users/pp/data/Simulations/A08_Hydraulics_standalone/hainich"
scenario_name = "fine_vanGenuch_jul_diff_err"
input_path = os.path.join(root_output_directory, scenario_name,'input')
output_path = os.path.join(root_output_directory, scenario_name,'output')
post_path = os.path.join(root_output_directory, scenario_name,'post')

# %%
best_J =pd.read_csv(os.path.join(post_path,'parameters_best_J.csv'))
best_psi_stem = pd.read_csv(os.path.join(post_path,'parameters_best_psi_stem.csv'))
best_both = pd.read_csv(os.path.join(post_path,'parameters_best_both.csv'))

best_both.sort_values(by='rmse_com_avg').to_csv(f"{post_path}/best_both_sort.csv")

# %%
best_both
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     id     dts  dts_input  \
# 0                 0         68221       68221  68221  1800.0       1800
# 1                 1         64964       64964  64964  1800.0       1800
# 2                 2         18832       18832  18832  1800.0       1800
# 3                 3         85277       85277  85277  1800.0       1800
# 4                 4         89481       89481  89481  1800.0       1800
# ...             ...           ...         ...    ...     ...        ...
# 25595           195         87682       87682  87682  1800.0       1800
# 25596           196         41390       41390  41390  1800.0       1800
# 25597           197         78126       78126  78126  1800.0       1800
# 25598           198         84070       84070  84070  1800.0       1800
# 25599           199         84357       84357  84357  1800.0       1800
#
#        verbose  max_psi_leaf_change_per_hour  minimum_psi_leaf_multiplier  \
# ...

# %%
plt.hist(best_J['rmse_com_avg'], bins =60);
plt.hist(best_psi_stem['rmse_com_avg'], bins =60);
plt.hist(best_both['rmse_com_avg'], bins =60);

# %%
df_both = best_both.sort_values(by='rmse_com_avg').iloc[0:1000]
df_pstem = best_psi_stem.sort_values(by='rmse_psi_stem').iloc[0:1000]
df_J = best_J.sort_values(by='rmse_J').iloc[0:1000]

# %%
df_both
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     id     dts  dts_input  \
# 3000              0         38298       38298  38298  1800.0       1800
# 4600              0         42125       42125  42125  1800.0       1800
# 20200             0         29749       29749  29749  1800.0       1800
# 22200             0          2200        2200   2200  1800.0       1800
# 17000             0         49818       49818  49818  1800.0       1800
# ...             ...           ...         ...    ...     ...        ...
# 17207             7         39429       39429  39429  1800.0       1800
# 25412            12          4694        4694   4694  1800.0       1800
# 9209              9         18482       18482  18482  1800.0       1800
# 14408             8         38619       38619  38619  1800.0       1800
# 1203              3         34142       34142  34142  1800.0       1800
#
#        verbose  max_psi_leaf_change_per_hour  minimum_psi_leaf_multiplier  \
# ...

# %%
df_J[['rmse_J', 'rmse_psi_stem','rmse_com_avg']][0:2]
# Out:
#          rmse_J  rmse_psi_stem  rmse_com_avg
# 14600  0.000085       0.110983      0.953593
# 15400  0.000086       0.147535      1.227759

# %%
df_pstem[['rmse_J', 'rmse_psi_stem','rmse_com_avg']][0:2]
# Out:
#          rmse_J  rmse_psi_stem  rmse_com_avg
# 6600   0.000233       0.072980      0.881792
# 15200  0.000144       0.073383      0.756184

# %%
df_both[['rmse_J', 'rmse_psi_stem','rmse_com_avg']][0:2]
# Out:
#         rmse_J  rmse_psi_stem  rmse_com_avg
# 3000  0.000119       0.074169      0.727190
# 4600  0.000109       0.077428      0.737094

# %%
df_both
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     id     dts  dts_input  \
# 8200              0         18614       18614  18614  1800.0       1800
# 6800              0         17464       17464  17464  1800.0       1800
# 5800              0          4038        4038   4038  1800.0       1800
# 18800             0          7291        7291   7291  1800.0       1800
# 0                 0         27949       27949  27949  1800.0       1800
# ...             ...           ...         ...    ...     ...        ...
# 6004              4          4990        4990   4990  1800.0       1800
# 3807              7         29918       29918  29918  1800.0       1800
# 18408             8         23017       23017  23017  1800.0       1800
# 17203             3          7842        7842   7842  1800.0       1800
# 2007              7          8623        8623   8623  1800.0       1800
#
#        verbose  max_psi_leaf_change_per_hour  minimum_psi_leaf_multiplier  \
# ...

# %%
vars = ['psi_leaf_50_close', 'd_50_close','stem_hydraulic_capacitance', 'k_xylem_sat','huber_value',  'leaf_hydraulic_capacitance', 'psi50_xylem','leaf_area_index', 'g0', 'g1', 'k_soil_sat0', 'psi_soil_sat0','jackson_root_beta', 'theta_s0', 'pore_0', 'theta_r0', 'anet_max', 'root_area_index', 'tree_density' ]

for var in vars:
    
    if var == 'leaf_hydraulic_capacitance':
        plt.hist(np.log10(df_pstem[var]), alpha = 0.5, bins = 20);
        plt.hist(np.log10(df_J[var]), alpha = 0.5, bins = 20);
        plt.hist(np.log10(df_both[var]), alpha = 0.5, bins = 20);
    elif var == 'k_soil_sat0':
        plt.hist(np.log10(df_pstem[var]), alpha = 0.5, bins = 20);
        plt.hist(np.log10(df_J[var]), alpha = 0.5, bins = 20);
        plt.hist(np.log10(df_both[var]), alpha = 0.5, bins = 20);
    else:
        plt.hist(df_pstem[var], alpha = 0.5, bins = 20, label = 'stem');
        plt.hist(df_J[var], alpha = 0.5, bins = 20, label = 'J');
        plt.hist(df_both[var], alpha = 0.5, bins = 20, label = 'both');
    
    plt.legend()
    plt.title(var)
    plt.savefig(f"{post_path}/hist_{var}.png")
    plt.close()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
best_both.sort_values(by='rmse_com_avg').to_csv(f"{post_path}/best_both_sort.csv")

# %%
best_both.sort_values(by='rmse_com_avg').iloc[0:100]
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     id     dts  dts_input  \
# 8200              0         18614       18614  18614  1800.0       1800
# 6800              0         17464       17464  17464  1800.0       1800
# 5800              0          4038        4038   4038  1800.0       1800
# 18800             0          7291        7291   7291  1800.0       1800
# 0                 0         27949       27949  27949  1800.0       1800
# ...             ...           ...         ...    ...     ...        ...
# 3600              0          5779        5779   5779  1800.0       1800
# 16802             2         25956       25956  25956  1800.0       1800
# 12801             1          3235        3235   3235  1800.0       1800
# 2801              1            15          15     15  1800.0       1800
# 9402              2         25782       25782  25782  1800.0       1800
#
#        verbose  max_psi_leaf_change_per_hour  minimum_psi_leaf_multiplier  \
# ...

# %%
df_pstem
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     id     dts  dts_input  \
# 2000              0          1594        1594   1594  1800.0       1800
# 2200              0         17435       17435  17435  1800.0       1800
# 1400              0          6132        6132   6132  1800.0       1800
# 6600              0          9499        9499   9499  1800.0       1800
# 8300              0         16154       16154  16154  1800.0       1800
# ...             ...           ...         ...    ...     ...        ...
# 10708             8         19403       19403  19403  1800.0       1800
# 11108             8          1606        1606   1606  1800.0       1800
# 7807              7          3179        3179   3179  1800.0       1800
# 2210             10         18637       18637  18637  1800.0       1800
# 1210             10          8959        8959   8959  1800.0       1800
#
#        verbose  max_psi_leaf_change_per_hour  minimum_psi_leaf_multiplier  \
# ...

# %%
df_both.iloc[0:2]
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     id     dts  dts_input  \
# 3000              0         13936       13936  13936  1800.0       1800
# 10900             0         16232       16232  16232  1800.0       1800
#
#        verbose  max_psi_leaf_change_per_hour  minimum_psi_leaf_multiplier  \
# 3000     False                           1.0                          4.0
# 10900    False                           1.0                          4.0
#
#       conductivity_fraction_type  ...  solver_precision  psi_soil_sat0  \
# 3000                     Weibull  ...      1.000000e-10      -0.000740
# 10900                    Weibull  ...      1.000000e-10      -0.001794
#
#         k_soil_sat0  theta_s0  theta_r0    pore_0    rmse_J    rmse_G  \
# 3000   1.770374e-07  0.482653  0.077181  0.485023  0.000189  0.000255
# 10900  2.482660e-07  0.488777  0.070496  0.480577  0.000196  0.000262
#
#        rmse_psi_stem  rmse_com_avg
# 3000        0.071502      0.806905
# ...

# %%
2*18/1000.0
# Out:
# 0.036

# %%
df_both
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     id     dts  dts_input  \
# 3000              0         13936       13936  13936  1800.0       1800
# 10900             0         16232       16232  16232  1800.0       1800
# 1700              0           229         229    229  1800.0       1800
# 5800              0          4024        4024   4024  1800.0       1800
# 8900              0         11698       11698  11698  1800.0       1800
# ...             ...           ...         ...    ...     ...        ...
# 2407              7          4966        4966   4966  1800.0       1800
# 12107             7         15483       15483  15483  1800.0       1800
# 607               7         10399       10399  10399  1800.0       1800
# 9408              8          5506        5506   5506  1800.0       1800
# 1910             10         17450       17450  17450  1800.0       1800
#
#        verbose  max_psi_leaf_change_per_hour  minimum_psi_leaf_multiplier  \
# ...
