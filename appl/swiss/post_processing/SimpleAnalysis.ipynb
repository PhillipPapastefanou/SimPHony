# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os
from pathlib import Path

# %%
root_output_directory = "/Users/pp/data/Simulations/A08_SimPHony/swiss"
sorted(Path(root_output_directory).iterdir(), key=os.path.getmtime)
# Out:
# [PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/wcont_full_1E6'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/wcont_full_1E7'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/wcont_full_1E7_closer'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/wcont_full_1E7_closer_Anet_g1'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/2023swp'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/2023swp_red_1'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/2023swp_red_2'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/2023swp_red_2_logit'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/2023swp_red_2_sustain'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/test'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/2023_indiv_test'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/2023_indiv_2E7'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/2023_indiv_2E7_red'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/11_05_indiv_all'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/11_05_indiv_red'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/11_05_nstdn_red'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/11_06_nstdn_1E8'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/2023swp_red_3'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/11_05_nstdn'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/11_06_nstdn_change_1E7'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/.DS_Store'),
#  PosixPath('/Users/pp/data/Simulations/A08_SimPHony/swiss/11_07_nstdn_g0')]

# %%
scenario_name = "11_07_nstdn_g0"
input_path = os.path.join(root_output_directory, scenario_name,'input')
output_path = os.path.join(root_output_directory, scenario_name,'output')
post_path = os.path.join(root_output_directory, scenario_name,'post')

# %%
df =pd.read_csv(os.path.join(post_path,'parameters_best_0.csv'))

# %%
range_real = [0, 1, 3, 4, 6, 7, 9, 10, 11, 12, 13]
range_alive = [1, 4, 9, 10, 11, 12, 13]
range_dead = [0, 3, 6, 7]

# %%
df_dead_list = []
for id in range_dead:
    df =pd.read_csv(os.path.join(post_path,f'parameters_best_{id}.csv')).sort_values(by=[f't{id}'])
    df.reset_index(inplace=True)
    df_dead_list.append(df)
df_alive = pd.read_csv(os.path.join(post_path,f'parameters_best_mean_alive.csv')).sort_values(by=['alive_mean'])
df_alive.reset_index(inplace=True)

# %%
vars = ['psi_leaf_50_close', 'd_50_close','stem_hydraulic_capacitance', 'k_xylem_sat','huber_value',  'leaf_hydraulic_capacitance', 'psi50_xylem','leaf_area_index', 'g0', 'g1', 'k_soil_sat0', 'psi_soil_sat0','jackson_root_beta', 'theta_s0', 'pore_0', 'theta_r0', 'anet_max', 'root_area_index', 'tree_density','wcont_sigma_deviation','g_bark' ]

# %%
num = 1000
for var in vars:
    
    fig = plt.figure(figsize=(10,10))
    
    for i in range(4):
        ax = fig.add_subplot(2,2,i+1)
        
        if var == 'leaf_hydraulic_capacitance':
            data_dead = np.log10(df_dead_list[i][var][:num])
            data_alive = np.log10(df_alive[var][:num])
        elif var == 'k_soil_sat0':
            data_dead = np.log10(df_dead_list[i][var][:num])
            data_alive = np.log10(df_alive[var][:num])
        else:
            data_dead = df_dead_list[i][var][:num]
            data_alive = df_alive[var][:num]
    
        ax.hist(data_alive, alpha=0.5, label = 'alive')
        ax.hist(data_dead, alpha = 0.5, label = 'dead')
        ax.set_xlabel(var)
        ax.legend()
    plt.savefig(f"{post_path}/hist_{var}.png")
    plt.close(fig)

# %%
for i in range(4):
    print(df_dead_list[i][f't{range_dead[i]}'][0:1000].mean())
# Out:
# 0.5888748183110045
# 0.6097490400697985
# 1.3666905639790963
# 0.9627122099708526

# %%
0.5490351157105169
0.5834358037163484
1.2319278606564419
0.8107530894394924
# Out:
# 0.8107530894394924

# %%
df_dead_list[3][0:3]
# Out:
#    index  Unnamed: 0.1  Unnamed: 0     id     dts  dts_input  verbose  \
# 0  16700             0       66888  66888  1800.0       1800    False
# 1   5500             0       73753  73753  1800.0       1800    False
# 2  12700             0       58912  58912  1800.0       1800    False
#
#    max_psi_leaf_change_per_hour  minimum_psi_leaf_multiplier  \
# 0                           1.0                          4.0
# 1                           1.0                          4.0
# 2                           1.0                          4.0
#
#   conductivity_fraction_type  ...         t5        t6        t7         t8  \
# 0                    Weibull  ...  18.185007  4.603258  0.907213  18.053733
# 1                    Weibull  ...  17.029521  4.191258  0.911091  16.898964
# 2                    Weibull  ...  18.894802  4.796218  0.911975  18.763133
#
#           t9        t10        t11        t12        t13  alive_mean
# 0  18.241638  11.065563  11.592047  11.042002  11.026262   12.181052
# 1  17.086034  10.340372  10.836411  10.317390  10.301000   11.389784
# 2  18.951498  11.495131  12.037468  11.472476  11.456243   12.652681
#
# [3 rows x 68 columns]
